# %% [markdown]
# source: https://www.kaggle.com/datasets/cheddad/miniddsm

# %%
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import random

import torch
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.io import read_image
from torch.utils.data import Dataset
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
import os
import cv2
import glob
from skimage import io

from skimage import data
from skimage import filters
from skimage.color import rgb2gray
from skimage.io import imread

# %%
malign = pd.read_excel('./../Datasets/Mini_DDSM_Upload/List_Cancer.xlsx')
benign = pd.read_excel('./../Datasets/Mini_DDSM_Upload/List_Benign.xlsx')
normal = pd.read_excel('./../Datasets/Mini_DDSM_Upload/List_Normal.xlsx')

malign['class'] = 'malign'
benign['class'] = 'benign'
normal['class'] = 'normal'

df = pd.concat([malign, benign, normal])
print(df.shape)
df.head(5)
# Out:
# (9684, 5)
#    View                                   fileName  Age  Density   class
# 0  RMLO  1_C_0001_1.RIGHT_MLO.LJPEG.1_highpass.png   65        2  malign
# 1  LMLO   2_C_0001_1.LEFT_MLO.LJPEG.1_highpass.png   65        2  malign
# 2   RCC   3_C_0001_1.RIGHT_CC.LJPEG.1_highpass.png   65        2  malign
# 3   LCC    4_C_0001_1.LEFT_CC.LJPEG.1_highpass.png   65        2  malign
# 4  RMLO  5_C_0002_1.RIGHT_MLO.LJPEG.1_highpass.png   72        2  malign

# %%
# unique_malign = malign['fileName'].str.split('_').str.get(2).unique()
# unique_benign = benign['fileName'].str.split('_').str.get(2).unique()
# unique_normal = normal['fileName'].str.split('_').str.get(2).unique()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='class')
plt.show()

# %%
fig = plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Density', hue='class', palette='Purples')
plt.show()

# %% [markdown]
# # Malignant

# %%
img = plt.imread('./../Datasets/Mini_DDSM_Upload/Cancer/1109_C_0159_1.RIGHT_MLO.LJPEG.1_highpass.png')
fig = plt.figure(figsize=(8,8))
plt.imshow(img, cmap='gray')
plt.show()

# %%
img = plt.imread('./../Datasets/Mini_DDSM_Upload/Cancer/1110_C_0159_1.LEFT_MLO.LJPEG.1_highpass.png')
fig = plt.figure(figsize=(8,8))
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# # Beningn

# %%
img = plt.imread('./../Datasets/Mini_DDSM_Upload/Benign/1406_C_0364_1.LEFT_MLO.LJPEG.1_highpass.png')
fig = plt.figure(figsize=(8,8))
plt.imshow(img, cmap='gray')
plt.show()

# %% [markdown]
# # Normal

# %%
img = plt.imread('./../Datasets/Mini_DDSM_Upload/Normal/2432_A_1956_1.RIGHT_CC.LJPEG.1_highpass.png')
fig = plt.figure(figsize=(8,8))
plt.imshow(img, cmap='gray')
plt.show()
